# %% [markdown]
# # BME3053C - Computer Applications for BME
#
# <br/>
#
# <h1 align="center">GitHub Copilot Introduction</h1>
#
# ---
#
# <center><h2>Introduction to AI-Assisted Programming</h2></center>
#
# <br/>

# %% [markdown]
# # What is GitHub Copilot?
#
# GitHub Copilot is an AI pair programmer that helps you write code faster and with less effort. It works by:
#
# - Suggesting whole lines or blocks of code as you type
# - Converting comments into working code
# - Helping you understand and work with unfamiliar libraries
# - Offering multiple suggestions for you to choose from
# - Learning from your coding style and preferences
#
# # Getting Started with Copilot
#
# 1. **Access Copilot through GitHub Student Developer Pack**:
#    - Sign up for the [GitHub Student Developer Pack](https://education.github.com/pack)
#    - Once approved, activate your free Copilot subscription
#
# 2. **Install Copilot in Your Development Environment**:
#    - VS Code: Install the "GitHub Copilot" extension
#    - GitHub Codespaces: Copilot is available by default
#    - JupyterLab: Install the Copilot extension
#
# 3. **Verify Installation**:
#    - Look for the Copilot icon in your editor's status bar
#    - The icon should be active (not grayed out)
#    - You might need to sign in to GitHub to activate Copilot

# %% [markdown]
# # Switching AI Models in Copilot
#
# GitHub Copilot offers different AI models to help with various coding tasks. Here's how to switch between them:
#
# ## Available Models
#
# - **Default (GPT-3.5 Turbo)**: The standard model for general coding assistance
# - **GPT-4**: More powerful model with enhanced code understanding and generation capabilities
# - **Copilot Chat**: Conversational interface for complex queries and explanations
#
# ## How to Switch Models
#
# 1. **In VS Code**:
#     - Click on the Copilot icon in the status bar
#     - Select "GitHub Copilot: Switch Model"
#     - Choose your preferred model from the dropdown menu
#
# 2. **Using Command Palette**:
#     - Press `Ctrl+Shift+P` (Windows/Linux) or `Cmd+Shift+P` (Mac)
#     - Type "GitHub Copilot: Switch Model"
#     - Select the desired model
#
# 3. **In Copilot Chat**:
#     - Type `/model` followed by the model name
#     - Example: `/model gpt-4`
#
# ## When to Use Different Models
#
# - **Default Model**: Everyday coding tasks, quick suggestions
# - **GPT-4**: Complex algorithms, thorough code explanations, challenging problems
# - **Specialized Models**: Domain-specific coding (when available)
#
# Remember that more powerful models might be slower to respond or have usage limitations based on your subscription plan.

# %% [markdown]
# # Basic Usage
#
# ## 1. Code Completion
#
# Copilot provides suggestions as you type. Let's try some examples:
#
# 1. Start typing a function definition:
# ```python
# def calculate_bmi(weight, height):
#     # Calculate BMI using weight in kg and height in meters
# ```
#
# 2. Copilot will suggest the implementation. Press Tab to accept or keep typing for different suggestions.

# %%
def calculate_bmi(weight, height):
    # Calculate BMI using weight in kg and height in meters
    if height <= 0:
        raise ValueError("Height must be greater than zero.")
    if weight <= 0:
        raise ValueError("Weight must be greater than zero.")
    bmi = weight / (height ** 2)
    return round(bmi, 2)

def bmi_category(bmi):
    # Determine BMI category based on the calculated BMI
    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi < 24.9:
        return "Normal weight"
    elif 25 <= bmi < 29.9:
        return "Overweight"
    else:
        return "Obesity"
def main():
    # Example usage
    try:
        weight = float(input("Enter your weight in kg: "))
        height = float(input("Enter your height in meters: "))
        bmi = calculate_bmi(weight, height)
        category = bmi_category(bmi)
        print(f"Your BMI is {bmi} and you are classified as {category}.")
    except ValueError as e:
        print(e)
if __name__ == "__main__":
    main()
# This code calculates BMI and categorizes it
# It includes error handling for invalid inputs
# The code is structured to be reusable and maintainable
# The functions are defined separately for clarity
# The main function handles user input and output
# The code is designed to be user-friendly and informative
# Out:
# Your BMI is 1.88 and you are classified as Underweight.

# %% [markdown]
# ## 2. Comment-to-Code
#
# One of Copilot's most powerful features is generating code from comments:

# %%
# Create a function that converts temperature from Celsius to Fahrenheit
# Include input validation and round to 2 decimal places



# Try typing this comment and let Copilot suggest the implementation

def celsius_to_fahrenheit(celsius):
    """
    Convert temperature from Celsius to Fahrenheit
    Args:
        celsius (float): Temperature in Celsius
    Returns:
        float: Temperature in Fahrenheit, rounded to 2 decimal places
    """
    # Input validation
    if not isinstance(celsius, (int, float)):
        raise TypeError("Temperature must be a number")
    
    # Convert to Fahrenheit using the formula: °F = (°C × 9/5) + 32
    fahrenheit = (celsius * 9/5) + 32
    return round(fahrenheit, 2)

# Example usage
def main():
    try:
        temp = float(input("Enter temperature in Celsius: "))
        result = celsius_to_fahrenheit(temp)
        print(f"{temp}°C is equal to {result}°F")
    except ValueError:
        print("Please enter a valid number")
    except TypeError as e:
        print(e)

if __name__ == "__main__":
    main()
# Out:
# 28.0°C is equal to 82.4°F

# %% [markdown]
# ## 3. Working with Libraries
#
# Copilot is particularly helpful when working with libraries. It can suggest proper import statements and usage patterns:

# %%
# Create a scatter plot using matplotlib with the following features:
# - Random data points
# - Custom colors based on point values
# - A trend line
# - Proper labels and title
# - A legend
# - Proper

# Let Copilot suggest the implementation
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Generate random data
np.random.seed(42)  # for reproducibility
x = np.random.rand(50)
y = 0.5 * x + np.random.normal(0, 0.1, 50)  # Create correlated data

# Calculate trend line
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
line = slope * x + intercept

# Create color map based on y values
colors = y

# Create the plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(x, y, c=colors, cmap='viridis', 
                     alpha=0.6, label='Data points')
plt.plot(x, line, color='red', label=f'Trend line (R² = {r_value**2:.3f})')

# Customize the plot
plt.title('Random Data with Trend Line', fontsize=12, pad=15)
plt.xlabel('X Values', fontsize=10)
plt.ylabel('Y Values', fontsize=10)

# Add color bar
plt.colorbar(scatter, label='Y Value Magnitude')

# Add legend
plt.legend(loc='upper left')

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from ipywidgets import interact, FloatSlider
# %matplotlib inline

def plot_with_slope(slope_factor):
    # Generate random data
    np.random.seed(42)  # for reproducibility
    x = np.random.rand(50)
    y = slope_factor * x + np.random.normal(0, 0.1, 50)  # Adjustable slope
    
    # Calculate trend line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
    line = slope * x + intercept
    
    # Create the plot
    plt.figure(figsize=(10, 6))
    scatter = plt.scatter(x, y, c=y, cmap='viridis', 
                         alpha=0.6, label='Data points')
    plt.plot(x, line, color='red', label=f'Trend line (R² = {r_value**2:.3f})')
    
    # Customize the plot
    plt.title(f'Random Data with Trend Line (Slope Factor: {slope_factor:.2f})', 
             fontsize=12, pad=15)
    plt.xlabel('X Values', fontsize=10)
    plt.ylabel('Y Values', fontsize=10)
    plt.ylim(-5, 5)  # Set y-axis limits
    
    # Add color bar
    plt.colorbar(scatter, label='Y Value Magnitude')
    
    # Add legend
    plt.legend(loc='upper left')
    
    # Add grid
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Adjust layout
    plt.tight_layout()
    plt.show()

# Create interactive slider
interact(plot_with_slope, 
    slope_factor=FloatSlider(
        value=0.5,
        min=-5.0,
        max=5.0,
        step=0.1,
        description='Slope:',
        continuous_update=False
    ))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       2 import numpy as np
#       3 from scipy import stats
# ----> 4 from ipywidgets import interact, FloatSlider
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       7 def plot_with_slope(slope_factor):
#       8     # Generate random data
#
# ModuleNotFoundError: No module named 'ipywidgets'

# %% [markdown]
# ## 4. Keyboard Shortcuts for Copilot
#
# Here are all the keyboard shortcuts to enhance your productivity with Copilot:
#
# ### General Shortcuts
# - **Accept Suggestion**: Press `Tab` to accept the current suggestion.
# - **Reject Suggestion**: Press `Esc` to dismiss the suggestion.
# - **Trigger Suggestion**: Press `Ctrl + Space` (Windows/Linux) or `Cmd + Space` (Mac) to manually trigger Copilot suggestions.
#
# ### Navigating Suggestions
# - **Cycle Through Suggestions**:
#     - Press `Alt + ]` (Windows/Linux) or `Option + ]` (Mac) to see the next suggestion.
#     - Press `Alt + [` (Windows/Linux) or `Option + [` (Mac) to go back to the previous suggestion.
#
# ### Copilot Panel
# - **Open Copilot Panel**: Press `Ctrl + Enter` (Windows/Linux) or `Cmd + Enter` (Mac) to open the Copilot panel for more suggestions.
#
# ### Inline Suggestions
# - **Show Next Inline Suggestion**: Press `Alt + \` (Windows/Linux) or `Option + \` (Mac).
# - **Show Previous Inline Suggestion**: Press `Alt + Shift + \` (Windows/Linux) or `Option + Shift + \` (Mac).
#
# ### Dismiss Suggestions
# - **Dismiss Inline Suggestion**: Press `Esc`.
#
# ### Ghost Text
# - **Accept Word**: Press `Ctrl + Right Arrow` (Windows/Linux) or `Cmd + Right Arrow` (Mac) to accept one word at a time.
# - **Accept Line**: Press `Ctrl + End` (Windows/Linux) or `Cmd + End` (Mac) to accept the rest of the line.
#
# ### Chat Features
# - **Open Copilot Chat**: Press `Ctrl + Shift + I` (Windows/Linux) or `Cmd + Shift + I` (Mac).
# - **Send Message in Chat**: Press `Shift + Enter` or click the send button.
#
# These shortcuts can help you navigate and utilize Copilot more effectively while coding.

# %% [markdown]
# ## 5. Whole File Generation
#
# Copilot can generate entire files based on a description. Start with a detailed comment at the top of the file:
# ```python
# # Create a FastAPI application that:
# # 1. Implements a RESTful API for managing patient data
# # 2. Provides endpoints for adding, retrieving, and updating patient records
# # 3. Includes data validation and error handling
# # 4. Implements authentication for secure access
# # 5. Returns data in JSON format with proper status codes
# ```
#
# ## 6. Test Generation
#
# Copilot can help write tests for your code:

# %%
def calculate_dosage(weight, age, condition):
    """Calculate medication dosage based on patient parameters."""
    # Validate that weight and age are positive values
    if weight <= 0 or age < 0:
        raise ValueError("Weight and age must be positive")
    
    # Calculate the base dosage as twice the weight
    base_dosage = weight * 2
    
    # Adjust dosage for children under 12 years old
    if age < 12:
        base_dosage *= 0.75
    
    # Increase dosage by 50% for severe conditions
    if condition == "severe":
        base_dosage *= 1.5
    
    # Return the final dosage rounded to 2 decimal places
    return round(base_dosage, 2)

# Import ipytest for running test cases in Jupyter Notebook
import ipytest

# Define pytest test cases for the calculate_dosage function
def test_calculate_dosage():
    # Test normal case for an adult
    assert calculate_dosage(70, 30, "normal") == 140.0
    # Test normal case for a child under 12
    assert calculate_dosage(50, 10, "normal") == 75.0
    # Test severe condition for a teenager
    assert calculate_dosage(80, 15, "severe") == 240.0
    # Test normal case for a young child
    assert calculate_dosage(60, 5, "normal") == 90.0

# Run the tests
ipytest.run("-v")
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.12.1, pytest-8.3.5, pluggy-1.5.0 -- /home/codespace/.python/current/bin/python3
# cachedir: .pytest_cache
# rootdir: /workspaces/BME3053C-Spring-2025/lessons-solved
# plugins: anyio-4.9.0
# collecting ... collected 1 item
#
# t_fe3a367af15e4ed6b8db159d43684f46.py::test_calculate_dosage PASSED                          [100%]
#
# ======================================== 1 passed in 0.01s =========================================
# <ExitCode.OK: 0>

# %% [markdown]
# # Best Practices
#
# 1. **Review Generated Code**:
#    - Always review and understand code before accepting it
#    - Check for potential security issues
#    - Verify that the code follows your project's standards
#
# 2. **Write Clear Comments**:
#    - Be specific about what you want
#    - Include important requirements in comments
#    - Mention edge cases and error handling needs
#
# 3. **Iterative Refinement**:
#    - Start with a basic implementation
#    - Add comments for additional features
#    - Let Copilot help refactor and improve the code

# %% [markdown]
# ### ✏️ Exercise Create a function that processes medical image data:
#    - Accept a numpy array representing an image
#    - Apply basic image processing (normalization, filtering)
#    - Return the processed image
#    - Include proper error handling

# %%
import numpy as np
from scipy.ndimage import gaussian_filter

def process_medical_image(image):
    """
    Process a medical image represented as a numpy array.
    
    Parameters:
        image (numpy.ndarray): Input image array.
    
    Returns:
        numpy.ndarray: Processed image array.
    
    Raises:
        ValueError: If the input is not a valid numpy array.
    """
    # Error handling: Check if the input is a valid numpy array
    if not isinstance(image, np.ndarray):
        raise ValueError("Input must be a numpy array.")
    
    if image.ndim != 2:
        raise ValueError("Input image must be a 2D array.")
    
    try:
        # Step 1: Normalize the image (scale pixel values to range [0, 1])
        normalized_image = (image - np.min(image)) / (np.max(image) - np.min(image))
        
        # Step 2: Apply Gaussian filtering for noise reduction
        filtered_image = gaussian_filter(normalized_image, sigma=1)
        
        # Return the processed image
        return filtered_image
    
    except Exception as e:
        raise RuntimeError(f"An error occurred during image processing: {e}")

# Example usage of the process_medical_image function
# Create a synthetic medical image (2D numpy array)
image = np.random.rand(256, 256) * 255  # Random grayscale image
# Process the image using the defined function
processed_image = process_medical_image(image)
# Display the raw and processed images as two subplots
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Raw image subplot
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title("Raw Medical Image")
plt.colorbar()

# Processed image subplot
plt.subplot(1, 2, 2)
plt.imshow(processed_image, cmap='gray')
plt.title("Processed Medical Image")
plt.colorbar()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✏️ Exercise: Write a class for managing patient records
#    - Include methods for adding, updating, and retrieving records
#    - Implement data validation
#    - Add methods for basic statistical analysis

# %%
class PatientRecords:
    """
    A class to manage patient records, including adding, updating, retrieving,
    and performing basic statistical analysis.
    """
    def __init__(self):
        # Initialize an empty dictionary to store patient records
        self.records = {}

    def add_record(self, patient_id, name, age, weight, condition):
        """
        Add a new patient record.

        Parameters:
            patient_id (str): Unique identifier for the patient.
            name (str): Name of the patient.
            age (int): Age of the patient.
            weight (float): Weight of the patient in kilograms.
            condition (str): Medical condition of the patient.

        Raises:
            ValueError: If any input data is invalid.
        """
        if not isinstance(patient_id, str) or not patient_id:
            raise ValueError("Patient ID must be a non-empty string.")
        if not isinstance(name, str) or not name:
            raise ValueError("Name must be a non-empty string.")
        if not isinstance(age, int) or age <= 0:
            raise ValueError("Age must be a positive integer.")
        if not isinstance(weight, (int, float)) or weight <= 0:
            raise ValueError("Weight must be a positive number.")
        if not isinstance(condition, str) or not condition:
            raise ValueError("Condition must be a non-empty string.")

        self.records[patient_id] = {
            "name": name,
            "age": age,
            "weight": weight,
            "condition": condition
        }

    def update_record(self, patient_id, **kwargs):
        """
        Update an existing patient record.

        Parameters:
            patient_id (str): Unique identifier for the patient.
            kwargs: Key-value pairs of fields to update.

        Raises:
            KeyError: If the patient ID does not exist.
            ValueError: If any input data is invalid.
        """
        if patient_id not in self.records:
            raise KeyError(f"No record found for patient ID: {patient_id}")

        for key, value in kwargs.items():
            if key not in self.records[patient_id]:
                raise ValueError(f"Invalid field: {key}")
            if key == "age" and (not isinstance(value, int) or value <= 0):
                raise ValueError("Age must be a positive integer.")
            if key == "weight" and (not isinstance(value, (int, float)) or value <= 0):
                raise ValueError("Weight must be a positive number.")
            self.records[patient_id][key] = value

    def get_record(self, patient_id):
        """
        Retrieve a patient record.

        Parameters:
            patient_id (str): Unique identifier for the patient.

        Returns:
            dict: The patient's record.

        Raises:
            KeyError: If the patient ID does not exist.
        """
        if patient_id not in self.records:
            raise KeyError(f"No record found for patient ID: {patient_id}")
        return self.records[patient_id]

    def get_average_age(self):
        """
        Calculate the average age of all patients.

        Returns:
            float: The average age.

        Raises:
            ValueError: If no records exist.
        """
        if not self.records:
            raise ValueError("No records available to calculate average age.")
        return sum(record["age"] for record in self.records.values()) / len(self.records)

    def get_average_weight(self):
        """
        Calculate the average weight of all patients.

        Returns:
            float: The average weight.

        Raises:
            ValueError: If no records exist.
        """
        if not self.records:
            raise ValueError("No records available to calculate average weight.")
        return sum(record["weight"] for record in self.records.values()) / len(self.records)

    def get_patient_count(self):
        """
        Get the total number of patients.

        Returns:
            int: The number of patients.
        """
        return len(self.records)
    
# Example usage of the PatientRecords class
patient_records = PatientRecords()
# Adding records
patient_records.add_record("P001", "John Doe", 30, 70.0, "Healthy")
patient_records.add_record("P002", "Jane Smith", 25, 60.0, "Healthy")
patient_records.add_record("P003", "Alice Johnson", 40, 80.0, "Diabetic")
# Printing all patient records
for patient_id, record in patient_records.records.items():
    print(f"Patient ID: {patient_id}, Record: {record}")
# Updating a record
patient_records.update_record("P002", weight=62.5)
# Retrieving a record
record = patient_records.get_record("P002")
print(f"Record for P002: {record}")
# Getting average age and weight
average_age = patient_records.get_average_age()
average_weight = patient_records.get_average_weight()
print(f"Average Age: {average_age}")
print(f"Average Weight: {average_weight}")
# Getting total patient count
patient_count = patient_records.get_patient_count()
print(f"Total Patients: {patient_count}")
# Example of error handling
try:
    patient_records.update_record("P999", weight=65.0)  # Non-existent ID
except KeyError as e:
    print(e)
# Example of error handling for invalid input
try:
    patient_records.add_record("", "Invalid Patient", -5, -70.0, "")
except ValueError as e:
    print(e)
# Example of error handling for empty records
try:
    empty_records = PatientRecords()
    empty_records.get_average_age()
except ValueError as e: 
    print(e)
# Example of error handling for invalid field update
# Out:
# Patient ID: P001, Record: {'name': 'John Doe', 'age': 30, 'weight': 70.0, 'condition': 'Healthy'}
# Patient ID: P002, Record: {'name': 'Jane Smith', 'age': 25, 'weight': 60.0, 'condition': 'Healthy'}
# Patient ID: P003, Record: {'name': 'Alice Johnson', 'age': 40, 'weight': 80.0, 'condition': 'Diabetic'}
# Record for P002: {'name': 'Jane Smith', 'age': 25, 'weight': 62.5, 'condition': 'Healthy'}
# Average Age: 31.666666666666668
# Average Weight: 70.83333333333333
# Total Patients: 3
# 'No record found for patient ID: P999'
# Patient ID must be a non-empty string.
# No records available to calculate average age.

# %% [markdown]
# ### ✏️ Exercise: Create a data visualization dashboard
#    - Use pandas for data manipulation
#    - Create multiple types of plots using matplotlib
#    - Add interactive elements

# %%
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact, Dropdown, IntSlider

# Sample dataset
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 40, 45],
    "Weight": [55, 70, 68, 80, 60],
    "Height": [160, 175, 170, 180, 165],
    "Condition": ["Healthy", "Diabetic", "Healthy", "Hypertensive", "Healthy"]
}
df = pd.DataFrame(data)

# Function to display a bar plot
def plot_bar(column):
    plt.figure(figsize=(8, 5))
    df[column].value_counts().plot(kind="bar", color="skyblue")
    plt.title(f"Bar Plot of {column}", fontsize=14)
    plt.xlabel(column, fontsize=12)
    plt.ylabel("Count", fontsize=12)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.show()

# Function to display a scatter plot
def plot_scatter(x_column, y_column):
    plt.figure(figsize=(8, 5))
    plt.scatter(df[x_column], df[y_column], color="green", alpha=0.7)
    plt.title(f"Scatter Plot: {x_column} vs {y_column}", fontsize=14)
    plt.xlabel(x_column, fontsize=12)
    plt.ylabel(y_column, fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.show()

# Function to filter data by age and display a summary
def filter_data(min_age, max_age):
    filtered_df = df[(df["Age"] >= min_age) & (df["Age"] <= max_age)]
    print(f"Filtered Data (Age {min_age}-{max_age}):")
    display(filtered_df)

# Interactive bar plot
print("Interactive Bar Plot:")
interact(plot_bar, column=Dropdown(options=df.columns, description="Column:"))

# Interactive scatter plot
print("\nInteractive Scatter Plot:")
interact(plot_scatter, 
         x_column=Dropdown(options=df.columns, description="X-axis:"),
         y_column=Dropdown(options=df.columns, description="Y-axis:"))

# Interactive data filter
print("\nInteractive Data Filter:")
interact(filter_data, 
         min_age=IntSlider(value=20, min=20, max=50, step=5, description="Min Age:"),
         max_age=IntSlider(value=50, min=20, max=50, step=5, description="Max Age:"))
# Out:
# Interactive Bar Plot:

# %% [markdown]
# # Conclusion
#
# GitHub Copilot is a powerful tool that can significantly enhance your coding productivity. Remember:
#
# - It's an assistant, not a replacement for understanding code
# - Always review and test generated code
# - Use it to learn new patterns and approaches
# - Combine it with your own knowledge and creativity
#
# As you continue to use Copilot, you'll develop a workflow that helps you write better code more efficiently while maintaining good coding practices.
